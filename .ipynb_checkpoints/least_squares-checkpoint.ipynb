# %%
from scipy.optimize import least_squares
import numpy as np
import matplotlib.pyplot as plt
import ares
from average_dTb import average_dTb
import os

# %%
sim = ares.simulations.Global21cm(radiative_transfer=False, verbose=False)
sim.run()

# %%
def dTb(theta, z):
    m_chi = theta[0]
    
    directory = "average_dTb/m_chi"+"{:.2f}".format(m_chi)
    if os.path.exists(directory):
        if np.size(os.listdir(directory)) < 150:
            more_random_v_stream = 150 - np.size(os.listdir(directory))
            print("{} more_random_v_streams will be generated for m_chi = {} GeV...".format(more_random_v_stream, m_chi))
        else:
            more_random_v_stream = 0
            z_array, dTb_averaged = np.load(directory+'_averaged.npy')
            print("Adequate files already exist for m_chi = {} GeV. Existing averaged dTb and z loaded.".format(m_chi))
            print("---"*15)
    else:
        more_random_v_stream = 150
        print("{} more random v_streams will be generated for m_chi = {} GeV...".format(more_random_v_stream, m_chi))
    
    if more_random_v_stream:
        z_array, dTb_averaged, m_chi = average_dTb(m_chi=m_chi, more_random_v_stream=more_random_v_stream, mpi=1, verbose=False)
    
    dTb = np.interp(z, z_array, dTb_averaged)
    return dTb

def fun(theta):
    residual = abs(dTb(theta, z_sample) - dTb_sample)
    return residual

# %%
z_sample = np.arange(10, 300, 5)

theta_true = [0.55]
dTb_accurate = dTb(theta_true, z_sample)

noise = 3
dTb_sample = dTb_accurate + noise * np.random.normal(size = z_sample.shape[0])
# Out:
# Adequate files already exist for m_chi = 0.55 GeV. No more random v_streams to be generated.
# Existing averaged dTb and z for m_chi = 0.55 GeV are loaded.

# %%
theta_guess = [0.1]
res = least_squares(fun, theta_guess, diff_step=0.1, bounds=(0, 10), xtol=1e-3)
# Out:
# Adequate files already exist for m_chi = 0.1 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.2 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.2 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.30000000000000004 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.3989873352652364 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.4989873352652364 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.6249852844322843 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.7249852844322843 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# 150 more random v_streams will be generated for m_chi = 0.5244826860894898 GeV...
# dark_matter_mass = 0.5244826860894898 GeV
# 24 cores working...
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# It costs 97.14 seconds to calculate dTb of 150 different initial_v_streams.
# Preprocessing 150 files of dTb for m_chi = 0.5244826860894898 GeV...
# 150 files have been interpolated.
# ---------------------------------------------
# Adequate files already exist for m_chi = 0.6244826860894898 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# 150 more random v_streams will be generated for m_chi = 0.4629027376588394 GeV...
# dark_matter_mass = 0.4629027376588394 GeV
# 24 cores working...
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# It costs 99.51 seconds to calculate dTb of 150 different initial_v_streams.
# Preprocessing 150 files of dTb for m_chi = 0.4629027376588394 GeV...
# 150 files have been interpolated.
# ---------------------------------------------
# 150 more random v_streams will be generated for m_chi = 0.5090876989818272 GeV...
# dark_matter_mass = 0.5090876989818272 GeV
# 24 cores working...
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# It costs 100.14 seconds to calculate dTb of 150 different initial_v_streams.
# Preprocessing 150 files of dTb for m_chi = 0.5090876989818272 GeV...
# 150 files have been interpolated.
# ---------------------------------------------
# Adequate files already exist for m_chi = 0.6090876989818271 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.5188646809461763 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.5115319444729145 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.5096987603545989 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.
# Adequate files already exist for m_chi = 0.5092404643250201 GeV. No more random v_streams to be generated.
# Existing Data loaded instead.

# %%
print(res.success)
print(res.status)
print('---'*15)
print('real value =',theta_true)
print('guess =', theta_guess)
print('fit =', res.x)

plt.figure(dpi=200)
plt.plot(z_sample, dTb_sample, label='sample, noise ={}'.format(noise))
plt.plot(z_sample, dTb_accurate, label = 'real value = {}'.format(theta_true[0]))
plt.plot(z_sample, dTb(res.x, z_sample), label = 'fit = {:.2f}'.format(res.x[0]))
plt.plot(sim.history['z'], sim.history['dTb'], label = 'default')
plt.xlim(0,300)
plt.ylim(-60,0)
plt.legend()
plt.show()
# Out:
# True
# 3
# ---------------------------------------------
# real value = [0.55]
# guess = [0.1]
# fit = [0.5090877]
# Adequate files already exist for m_chi = 0.5090876989818272 GeV. No more random v_streams to be generated.
# Existing averaged dTb and z for m_chi = 0.5090876989818272 GeV are loaded.
