# %%
from scipy.optimize import least_squares
import numpy as np
import matplotlib.pyplot as plt
import ares
from average_dTb import average_dTb
import os

# %%
# !python remote.py

# %%
sim = ares.simulations.Global21cm()
sim.run()
# Out:
# # Loaded $ARES/input/inits/inits_planck_TTTEEE_lowl_lowE_best.txt.
#
# ############################################################################
# ##                       ARES Simulation: Overview                        ##
# ############################################################################
# ## ---------------------------------------------------------------------- ##
# ## Source Populations                                                     ##
# ## ---------------------------------------------------------------------- ##
# ##           sfrd    sed  radio  O/IR  Lya    LW   LyC   Xray  RTE        ##
# ## pop #0 :  fcoll    yes    -     -     x     x     -     -     -        ##
# ## pop #1 : sfrd->0   yes    -     -     -     -     -     x     -        ##
# ## pop #2 : sfrd->0   yes    -     -     -     -     x     -     -        ##
# ## ---------------------------------------------------------------------- ##
# ...

# %%
def dTb(theta, z):
    m_chi = theta[0]
    
    directory = "average_dTb/m_chi"+"{:.2f}".format(m_chi)
    if os.path.exists(directory):
        if np.size(os.listdir(directory)) < 150:
            more_random_v_stream = 150 - np.size(os.listdir(directory))
            print("{} more_random_v_streams will be generated for m_chi = {} GeV.".format(more_random_v_stream, m_chi))
        else:
            more_random_v_stream = 0
            print("Adequate files already exist for m_chi = {} GeV. No more random v_streams to be generated.".format(m_chi))
    else:
        more_random_v_stream = 150
        print("{} more random v_streams will be generated for m_chi = {} GeV.".format(more_random_v_stream, m_chi))
    
    z_array, dTb_averaged, m_chi = average_dTb(m_chi=m_chi, more_random_v_stream=more_random_v_stream)
    
    dTb = np.interp(z, z_array, dTb_averaged)
    return dTb

# %%
z_sample = np.arange(10, 300, 5)

theta_true = [0.35]
dTb_accurate = dTb(theta_true, z_sample)

noise = 0.5
dTb_sample = dTb_accurate + noise * np.random.normal(size = z_sample.shape[0])
# Out:
# 146 more_random_v_streams will be generated for m_chi = 0.35 GeV.
# dark_matter_mass = 0.35 GeV
# initial_v_stream = 25269.00657759355 m/s
# initial_v_stream = 3.757004450086768e+04 m/s
# initial_v_stream = 9.628535290351203e+03 m/s
# initial_v_stream = 2.0404297648216652e+04 m/s
# initial_v_stream = 1.5568998465544193e+04 m/s
# initial_v_stream = 3.500509048566405e+04 m/s
# initial_v_stream = 3.631504681244793e+04 m/s
# initial_v_stream = 4.5160050752014875e+04 m/s
# initial_v_stream = 3.678115688657349e+04 m/s
# initial_v_stream = 3.720608793788405e+04 m/s
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# initial_v_stream = 4.8724511899000325e+04 m/s
# initial_v_stream = 3.0017088125258648e+04 m/s
# initial_v_stream = 1.918744577008169e+04 m/s
# ...

# %%
plt.plot(z_sample, dTb_sample)
plt.plot(z_sample, dTb_accurate)
plt.plot(sim.history['z'], sim.history['dTb'])
plt.xlim(0,300)
plt.ylim(-60,0)
# Out:
# (-60.0, 0.0)

# %%
def fun(theta):
    residual = abs(dTb(theta, z_sample) - dTb_sample)
    return residual

# %%
theta_guess = [0.01]
res = least_squares(fun, theta_guess, diff_step=0.1, bounds=(0, 10), xtol=1e-3)
# Out:
# 115 more_random_v_streams will be generated for m_chi = 0.01 GeV.
# dark_matter_mass = 0.01 GeV
# initial_v_stream = 36295.11702171838 m/s
# initial_v_stream = 4.870587833377627e+04 m/s
# initial_v_stream = 1.789469132147461e+04 m/s
# initial_v_stream = 3.798047586680415e+04 m/s
# initial_v_stream = 3.1323919555496475e+04 m/s
# initial_v_stream = 3.599760281646882e+04 m/s
# initial_v_stream = 9.696263662586705e+03 m/s
# initial_v_stream = 8.88988834679735e+03 m/s
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# initial_v_stream = 1.2410806686364154e+04 m/s
# initial_v_stream = 2.4207995366646905e+04 m/s
# initial_v_stream = 3.4974146139792094e+04 m/s
# initial_v_stream = 3.591043314112672e+04 m/s
# initial_v_stream = 2.4608010289887327e+04 m/s
# ...

# %%
res.status

# %%
res.x

# %%
plt.plot(z_sample, dTb_sample, label='sample')
plt.plot(z_sample, dTb_accurate, label = 'true')
plt.plot(z_sample, dTb(res.x, z_sample), label = 'fit')
plt.plot(sim.history['z'], sim.history['dTb'], label = 'default')
plt.xlim(0,300)
plt.ylim(-60,0)
plt.legend()

# %%
plt.plot(z_sample, dTb_sample, label='sample')
plt.plot(z_sample, dTb_accurate, label = 'true')
plt.plot(z_sample, dTb([0.40], z_sample), label = 'fit')
# plt.plot(sim.history['z'], sim.history['dTb'], label = 'default')
plt.xlim(0,300)
plt.ylim(-60,0)
plt.legend()

# %%
# plt.plot(z_sample, dTb_sample, label='sample')
# plt.plot(z_sample, dTb_accurate, label = 'true')
plt.figure(dpi=300)
z_sample = np.arange(10, 300, 5)
# plt.plot(z_sample, dTb([0.59], z_sample), label = '59')
plt.plot(z_sample, dTb([0.60], z_sample), label = '60')
plt.plot(z_sample, dTb([0.61], z_sample), label = '61')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.63], z_sample), label = '62')
plt.plot(z_sample, dTb([0.64], z_sample), label = '62')
plt.plot(z_sample, dTb([0.65], z_sample), label = '62')
plt.plot(z_sample, dTb([0.66], z_sample), label = '62')
plt.plot(z_sample, dTb([0.67], z_sample), label = '62')
plt.plot(z_sample, dTb([0.68], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
plt.plot(z_sample, dTb([0.62], z_sample), label = '62')
# plt.plot(sim.history['z'], sim.history['dTb'], label = 'default')
plt.xlim(0,300)
plt.ylim(-60,0)
plt.legend()

# %%
plt.savefig("60_61_62_so_close")

# %%
# plt.plot(z_sample, dTb_sample, label='sample')
# plt.plot(z_sample, dTb_accurate, label = 'true')
plt.figure(dpi=300)
z_sample = np.arange(10, 300, 5)
# plt.plot(z_sample, dTb([0.59], z_sample), label = '59')
plt.plot(z_sample, dTb([0.55], z_sample), label = '55')
plt.plot(z_sample, dTb([0.57], z_sample), label = '57')
plt.plot(z_sample, dTb([0.59], z_sample), label = '59')
# plt.plot(sim.history['z'], sim.history['dTb'], label = 'default')
plt.xlim(0,300)
plt.ylim(-60,0)
plt.legend()
# Out:
# 136 more_random_v_streams will be generated for m_chi = 0.55 GeV.
# dark_matter_mass = 0.55 GeV
# initial_v_stream = 40056.08197639586 m/s
# /usr/local/pace-apps/manual/packages/anaconda3/2022.05/lib/python3.9/site-packages/scipy/integrate/_ode.py:1350: UserWarning: lsoda: Excess work done on this call (perhaps wrong Dfun type).
#   warnings.warn('{:s}: {:s}'.format(self.__class__.__name__,
# initial_v_stream = 2.3161696879510877e+04 m/s
# initial_v_stream = 2.6399741865664782e+04 m/s
# initial_v_stream = 2.2351595800868352e+04 m/s
# initial_v_stream = 1.6901936996939297e+04 m/s
# initial_v_stream = 1.1120796380308999e+04 m/s
# initial_v_stream = 1.4528398394095593e+04 m/s
# initial_v_stream = 2.6336955900978748e+04 m/s
# initial_v_stream = 4.128159570500891e+04 m/s
# initial_v_stream = 3.020272184909218e+04 m/s
# initial_v_stream = 3.2547610023199286e+04 m/s
# initial_v_stream = 1.6059844021282654e+04 m/s
# initial_v_stream = 3.405520097718784e+04 m/s
# ...

# %%
from numpy.linalg import norm

def distance(theta):
    residual = dTb(theta, z_sample) - dTb_sample
    distance = norm(residual)
    return distance

# %%
mass_distance = np.array([0.1, distance([0.1])])
mass_distance = np.vstack((mass_distance, np.array([1, distance([1])])))
mass = (mass_distance[-1][0] + mass_distance[-2][0]) / 2
mass_distance = np.vstack((mass_distance, np.array([mass, distance([mass])])))
print(mass_distance)
# Out:
# dark_matter_mass = 0.1 GeV
# initial_v_stream = 19166.237008923887 m/s
# initial_v_stream = 1974.0210253762016 m/s
# It costs 27.39 seconds to calculate dTb of 2 different initial_v_streams.
# Preprocessing 172 files of dTb for m_chi = 0.1 GeV...
# 172 files have been interpolated.
# dark_matter_mass = 1 GeV
# initial_v_stream = 37246.098659738534 m/s
# initial_v_stream = 22174.91400025566 m/s
# It costs 21.82 seconds to calculate dTb of 2 different initial_v_streams.
# Preprocessing 158 files of dTb for m_chi = 1 GeV...
# 158 files have been interpolated.
# dark_matter_mass = 0.55 GeV
# initial_v_stream = 20533.080752840204 m/s
# initial_v_stream = 36888.400088407325 m/s
# It costs 51.62 seconds to calculate dTb of 2 different initial_v_streams.
# Preprocessing 12 files of dTb for m_chi = 0.55 GeV...
# 12 files have been interpolated.
# [[ 0.1        85.42542169]
#  [ 1.         35.85512321]
#  [ 0.55       23.65307503]]

# %%
if mass_distance[-1][1] > np.max((mass_distance[-2][1], mass_distance[-3][1])):
    print("something wrong.")
elif mass_distance[-2][1] < mass_distance[-3][1]:
    mass = (mass_distance[-2][0]+mass_distance[-1][0])/2
elif mass_distance[-2][1] > mass_distance[-3][1]:
    mass = (mass_distance[-3][0]+mass_distance[-1][0])/2

mass_distance = np.vstack((mass_distance, np.array([mass, distance([mass])])))
print(mass_distance)
# Out:
# something wrong.
# dark_matter_mass = 0.775 GeV
# initial_v_stream = 39466.86311287316 m/s
# initial_v_stream = 22319.2822678172 m/s
# It costs 22.29 seconds to calculate dTb of 2 different initial_v_streams.
# Preprocessing 4 files of dTb for m_chi = 0.775 GeV...
# 4 files have been interpolated.
# [[ 0.1        85.42542169]
#  [ 1.         35.85512321]
#  [ 0.55       23.65307503]
#  [ 0.775      63.05301491]
#  [ 0.775      58.02136485]]

# %%
ls
# Out:
# ares/           codecov.yml  least_squares.ipynb  remote.py*
# average_dTb/    dist/        LICENSE*             requirements.txt
# average_dTb.py  docs/        perf/                run_tests_local.sh*
# build/          examples/    __pycache__/         setup.py*
# CITATION*       input/       README.md            tests/

# %%
cd average_dTb/
# Out:
# /storage/coda1/p-jw254/0/bxia34/ares/average_dTb

# %%
ls
# Out:
# m_chi0.01/               m_chi1.04/              m_chi2.97_averaged.npy
# m_chi0.01_averaged.npy   m_chi1.04_averaged.npy  m_chi2.98/
# m_chi0.10/               m_chi1.05/              m_chi2.98_averaged.npy
# m_chi0.10_averaged.npy   m_chi1.05_averaged.npy  m_chi2.99/
# m_chi0.50/               m_chi1.15/              m_chi2.99_averaged.npy
# m_chi0.50_averaged.npy   m_chi1.15_averaged.npy  m_chi3.00/
# m_chi0.55/               m_chi1.51/              m_chi3.00_averaged.npy
# m_chi0.55_averaged.npy   m_chi1.51_averaged.npy  m_chi3.02/
# m_chi0.57/               m_chi1.93/              m_chi3.03/
# m_chi0.57_averaged.npy   m_chi2.00/              m_chi3.03_averaged.npy
# m_chi0.59/               m_chi2.00_averaged.npy  m_chi3.04/
# m_chi0.59_averaged.npy   m_chi2.02/              m_chi3.04_averaged.npy
# m_chi0.61/               m_chi2.02_averaged.npy  m_chi3.07/
# m_chi0.61_averaged.npy   m_chi2.07/              m_chi3.07_averaged.npy
# ...

# %%
ls m_chi0.62/ | wc -l
# Out:
# 360

# %%
filenames = os.listdir("m_chi0.62")

# %%
for filename in filenames:
    data =
# Out:
# ['25098.npy',
#  '28792.npy',
#  '49300.npy',
#  '32071.npy',
#  '10098.npy',
#  '33492.npy',
#  '44038.npy',
#  '25273.npy',
#  '23142.npy',
#  '22937.npy',
#  '41539.npy',
#  '28509.npy',
#  '16666.npy',
#  '27820.npy',
#  '20365.npy',
#  '29289.npy',
#  '15923.npy',
#  '38385.npy',
#  '14610.npy',
#  '43827.npy',
#  '26514.npy',
#  '33453.npy',
#  '29163.npy',
#  '27684.npy',
#  '26149.npy',
#  '42819.npy',
#  '22726.npy',
#  '11661.npy',
#  '42443.npy',
#  '22780.npy',
#  '18559.npy',
#  '26566.npy',
#  '18831.npy',
#  '18560.npy',
#  '23317.npy',
#  '27896.npy',
#  '15697.npy',
#  '42444.npy',
#  '35913.npy',
#  '18896.npy',
#  '40110.npy',
#  '51148.npy',
#  '32586.npy',
#  '25060.npy',
#  '27636.npy',
#  '34446.npy',
#  '16489.npy',
#  '22979.npy',
#  '18223.npy',
#  '29170.npy',
#  '26261.npy',
#  '37997.npy',
#  '28612.npy',
#  '19602.npy',
#  '17408.npy',
#  '41523.npy',
#  '31936.npy',
#  '28140.npy',
#  '19696.npy',
#  '9005.npy',
#  '19499.npy',
#  '25734.npy',
# ...
